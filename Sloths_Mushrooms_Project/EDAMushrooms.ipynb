# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0               c         n          k           e          e
# 1               c         b          k           e          c
# 2               c         b          n           e          c
# 3               c         n          n           e          e
# 4               w         b          k           t          e
# ...           ...       ...        ...         ...        ...
# 8119            c         b          y           e          ?
# 8120            c         b          y           e          ?
# 8121            c         b          n           e          ?
# 8122            c         n          b           t          ?
# 8123            c         b          y           e          ?
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                           s                        s                      w
# 1                           s                        s                      w
# 2                           s                        s                      w
# 3                           s                        s                      w
# 4                           s                        s                      w
# ...                       ...                      ...                    ...
# 8119                        s                        s                      o
# 8120                        s                        s                      o
# 8121                        s                        s                      o
# 8122                        s                        k                      w
# 8123                        s                        s                      o
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                         w         p          w           o         p
# 1                         w         p          w           o         p
# 2                         w         p          w           o         p
# 3                         w         p          w           o         p
# 4                         w         p          w           o         e
# ...                     ...       ...        ...         ...       ...
# 8119                      o         p          o           o         p
# 8120                      o         p          n           o         p
# 8121                      o         p          o           o         p
# 8122                      w         p          w           o         e
# 8123                      o         p          o           o         p
#
#      spore-print-color population habitat
# 0                    k          s       u
# 1                    n          n       g
# 2                    n          n       m
# 3                    k          s       u
# 4                    n          a       g
# ...                ...        ...     ...
# 8119                 b          c       l
# 8120                 b          v       l
# 8121                 b          c       l
# 8122                 w          v       l
# 8123                 o          c       l
#
# [8124 rows x 23 columns]

# %%
df['class'] = df['class'].replace(['p','e'],['Poisnous', 'Edible'])
df['cap-shape'] = df['cap-shape'].replace(['b','c','x','f','k','s'],['Bell','Conical','Convex','Flat','Knobbed','Sunken'])
df['cap-surface'] = df['cap-surface'].replace(['f','g','y','s'],['Fibrous','Grooves','Scaly','Smooth'])
df['cap-color'] = df['cap-color'].replace(['n','b','c','g','r','p','u','e','w','y'],['Brown','Buff','Cinnamon','Gray','Green','Pink','Purple','Red','White','Yellow'])
df['bruises'] = df['bruises'].replace(['t','f'],['Yes','No'])
df['odor'] = df['odor'].replace(['a','l','c','y','f','m','n','p','s'],['Almond','Anise','Creosote','Fishy','Foul','Musty','None','Pungent','Spicy'])
df['gill-attachment'] = df['gill-attachment'].replace(['a','d','f','n'],['Attached','Descending','Free','Notched'])
df['gill-spacing'] = df['gill-spacing'].replace(['c','w','d'],['Close','Crowded','Distant'])
df['gill-size'] = df['gill-size'].replace(['b','n'],['Broad','Narrow'])
df['gill-color'] = df['gill-color'].replace(['k','n','b','h','g','r','o','p','u','e','w','y'],['Black','Brown','Buff','Chocolate','Gray','Green','Orange','Pink','Purple','Red','White','Yellow'])
df['stalk-shape'] = df['stalk-shape'].replace(['e','t'],['Enlarging','Tapering'])
df['stalk-root'] = df['stalk-root'].replace(['b','c','u','e','z','r','?'],['Bulbous','Club','Cup','Equal','Rhizomorphs','Rooted',np.NaN])
df['stalk-surface-above-ring'] = df['stalk-surface-above-ring'].replace(['f','y','k','s'],['Fibrous','Scaly','Silky','Smooth'])
df['stalk-surface-below-ring'] = df['stalk-surface-above-ring'].replace(['f','y','k','s'],['Fibrous','Scaly','Silky','Smooth'])
df['stalk-color-above-ring'] = df['stalk-color-above-ring'].replace(['n','b','c','g','o','p','e','w','y'],['Brown','Buff','Cinnamon','Gray','Orange','Pink','Red','White','Yellow'])
df['stalk-color-below-ring'] = df['stalk-color-below-ring'].replace(['n','b','c','g','o','p','e','w','y'],['Brown','Buff','Cinnamon','Gray','Orange','Pink','Red','White','Yellow'])
df['veil-type'] = df['veil-type'].replace(['p','u'],['Partial','Universal'])
df['veil-color'] = df['veil-color'].replace(['n','o','w','y'],['Brown','Orange','White','Yellow'])
df['ring-number'] = df['ring-number'].replace(['n','o','t'],[np.NaN,1,2])
df['ring-type'] = df['ring-type'].replace(['c','e','f','l','n','p','s','z'],['Cobwebby','Evanescent','Flaring','Large',np.NaN,'Pendant','Sheating','Zone'])
df['spore-print-color'] = df['spore-print-color'].replace(['k','n','b','h','r','o','u','w','y'],['Black','Brown','Buff','Chocolate','Green','Orange','Purple','White','Yellow'])
df['population'] = df['population'].replace(['a','c','n','s','v','y'],['Abundant','Clustered','Numerous','Scattered','Several','Solitary'])
df['habitat'] = df['habitat'].replace(['g','l','m','p','u','w','d'],['Grasses','Leaves','Meadowns','Paths','Urban','Waste','Woods'])

# %%
df
# Out:
#          class cap-shape cap-surface cap-color bruises     odor  \
# 0     Poisnous    Convex      Smooth     Brown     Yes  Pungent
# 1       Edible    Convex      Smooth    Yellow     Yes   Almond
# 2       Edible      Bell      Smooth     White     Yes    Anise
# 3     Poisnous    Convex       Scaly     White     Yes  Pungent
# 4       Edible    Convex      Smooth      Gray      No     None
# ...        ...       ...         ...       ...     ...      ...
# 8119    Edible   Knobbed      Smooth     Brown      No     None
# 8120    Edible    Convex      Smooth     Brown      No     None
# 8121    Edible      Flat      Smooth     Brown      No     None
# 8122  Poisnous   Knobbed       Scaly     Brown      No    Fishy
# 8123    Edible    Convex      Smooth     Brown      No     None
#
#      gill-attachment gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0               Free        Close    Narrow      Black   Enlarging      Equal
# 1               Free        Close     Broad      Black   Enlarging       Club
# 2               Free        Close     Broad      Brown   Enlarging       Club
# 3               Free        Close    Narrow      Brown   Enlarging      Equal
# 4               Free      Crowded     Broad      Black    Tapering      Equal
# ...              ...          ...       ...        ...         ...        ...
# 8119        Attached        Close     Broad     Yellow   Enlarging        NaN
# 8120        Attached        Close     Broad     Yellow   Enlarging        NaN
# 8121        Attached        Close     Broad      Brown   Enlarging        NaN
# 8122            Free        Close    Narrow       Buff    Tapering        NaN
# 8123        Attached        Close     Broad     Yellow   Enlarging        NaN
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                      Smooth                   Smooth                  White
# 1                      Smooth                   Smooth                  White
# 2                      Smooth                   Smooth                  White
# 3                      Smooth                   Smooth                  White
# 4                      Smooth                   Smooth                  White
# ...                       ...                      ...                    ...
# 8119                   Smooth                   Smooth                 Orange
# 8120                   Smooth                   Smooth                 Orange
# 8121                   Smooth                   Smooth                 Orange
# 8122                   Smooth                   Smooth                  White
# 8123                   Smooth                   Smooth                 Orange
#
#      stalk-color-below-ring veil-type veil-color  ring-number   ring-type  \
# 0                     White   Partial      White          1.0     Pendant
# 1                     White   Partial      White          1.0     Pendant
# 2                     White   Partial      White          1.0     Pendant
# 3                     White   Partial      White          1.0     Pendant
# 4                     White   Partial      White          1.0  Evanescent
# ...                     ...       ...        ...          ...         ...
# 8119                 Orange   Partial     Orange          1.0     Pendant
# 8120                 Orange   Partial      Brown          1.0     Pendant
# 8121                 Orange   Partial     Orange          1.0     Pendant
# 8122                  White   Partial      White          1.0  Evanescent
# 8123                 Orange   Partial     Orange          1.0     Pendant
#
#      spore-print-color population   habitat
# 0                Black  Scattered     Urban
# 1                Brown   Numerous   Grasses
# 2                Brown   Numerous  Meadowns
# 3                Black  Scattered     Urban
# 4                Brown   Abundant   Grasses
# ...                ...        ...       ...
# 8119              Buff  Clustered    Leaves
# 8120              Buff    Several    Leaves
# 8121              Buff  Clustered    Leaves
# 8122             White    Several    Leaves
# 8123            Orange  Clustered    Leaves
#
# [8124 rows x 23 columns]

# %%
df.dtypes.value_counts()
# Out:
# object     22
# float64     1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# class                          0
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                   36
# ring-type                     36
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#          class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count     8124      8124        8124      8124    8124  8124            8124
# unique       2         6           4        10       2     9               2
# top     Edible    Convex       Scaly     Brown      No  None            Free
# freq      4208      3656        3244      2284    4748  3528            7914
# mean       NaN       NaN         NaN       NaN     NaN   NaN             NaN
# std        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# min        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# 25%        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# 50%        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# 75%        NaN       NaN         NaN       NaN     NaN   NaN             NaN
# max        NaN       NaN         NaN       NaN     NaN   NaN             NaN
#
#        gill-spacing gill-size gill-color stalk-shape stalk-root  \
# count          8124      8124       8124        8124       5644
# unique            2         2         12           2          4
# top           Close     Broad       Buff    Tapering    Bulbous
# freq           6812      5612       1728        4608       3776
# mean            NaN       NaN        NaN         NaN        NaN
# std             NaN       NaN        NaN         NaN        NaN
# min             NaN       NaN        NaN         NaN        NaN
# 25%             NaN       NaN        NaN         NaN        NaN
# 50%             NaN       NaN        NaN         NaN        NaN
# 75%             NaN       NaN        NaN         NaN        NaN
# max             NaN       NaN        NaN         NaN        NaN
#
#        stalk-surface-above-ring stalk-surface-below-ring  \
# count                      8124                     8124
# unique                        4                        4
# top                      Smooth                   Smooth
# freq                       5176                     5176
# mean                        NaN                      NaN
# std                         NaN                      NaN
# min                         NaN                      NaN
# 25%                         NaN                      NaN
# 50%                         NaN                      NaN
# 75%                         NaN                      NaN
# max                         NaN                      NaN
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# top                     White                  White   Partial      White
# freq                     4464                   4384      8124       7924
# mean                      NaN                    NaN       NaN        NaN
# std                       NaN                    NaN       NaN        NaN
# min                       NaN                    NaN       NaN        NaN
# 25%                       NaN                    NaN       NaN        NaN
# 50%                       NaN                    NaN       NaN        NaN
# 75%                       NaN                    NaN       NaN        NaN
# max                       NaN                    NaN       NaN        NaN
#
#         ring-number ring-type spore-print-color population habitat
# count   8088.000000      8088              8124       8124    8124
# unique          NaN         4                 9          6       7
# top             NaN   Pendant             White    Several   Woods
# freq            NaN      3968              2388       4040    3148
# mean       1.074184       NaN               NaN        NaN     NaN
# std        0.262086       NaN               NaN        NaN     NaN
# min        1.000000       NaN               NaN        NaN     NaN
# 25%        1.000000       NaN               NaN        NaN     NaN
# 50%        1.000000       NaN               NaN        NaN     NaN
# 75%        1.000000       NaN               NaN        NaN     NaN
# max        2.000000       NaN               NaN        NaN     NaN

# %%
df_copy = df.drop(columns='stalk-root',axis=1)

# %%
df_copy = df_copy.dropna()

# %%
df_copy.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df_copy.shape
# Out:
# (8088, 22)

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df[['class','cap-shape','cap-surface','cap-color']]
# 4,6,10
# Out:
#          class cap-shape cap-surface cap-color
# 0     Poisnous    Convex      Smooth     Brown
# 1       Edible    Convex      Smooth    Yellow
# 2       Edible      Bell      Smooth     White
# 3     Poisnous    Convex       Scaly     White
# 4       Edible    Convex      Smooth      Gray
# ...        ...       ...         ...       ...
# 8119    Edible   Knobbed      Smooth     Brown
# 8120    Edible    Convex      Smooth     Brown
# 8121    Edible      Flat      Smooth     Brown
# 8122  Poisnous   Knobbed       Scaly     Brown
# 8123    Edible    Convex      Smooth     Brown
#
# [8124 rows x 4 columns]

# %%
df[['class','gill-attachment', 'gill-spacing', 'gill-size', 'gill-color']]
# 2, 2, 2, 12
# Out:
#          class gill-attachment gill-spacing gill-size gill-color
# 0     Poisnous            Free        Close    Narrow      Black
# 1       Edible            Free        Close     Broad      Black
# 2       Edible            Free        Close     Broad      Brown
# 3     Poisnous            Free        Close    Narrow      Brown
# 4       Edible            Free      Crowded     Broad      Black
# ...        ...             ...          ...       ...        ...
# 8119    Edible        Attached        Close     Broad     Yellow
# 8120    Edible        Attached        Close     Broad     Yellow
# 8121    Edible        Attached        Close     Broad      Brown
# 8122  Poisnous            Free        Close    Narrow       Buff
# 8123    Edible        Attached        Close     Broad     Yellow
#
# [8124 rows x 5 columns]

# %%
df[['class','stalk-shape', 'stalk-root', 'stalk-surface-above-ring','stalk-surface-below-ring', 'stalk-color-above-ring','stalk-color-below-ring']]
# 2, 4, 4, 4, 9, 9
# Out:
#          class stalk-shape stalk-root stalk-surface-above-ring  \
# 0     Poisnous   Enlarging      Equal                   Smooth
# 1       Edible   Enlarging       Club                   Smooth
# 2       Edible   Enlarging       Club                   Smooth
# 3     Poisnous   Enlarging      Equal                   Smooth
# 4       Edible    Tapering      Equal                   Smooth
# ...        ...         ...        ...                      ...
# 8119    Edible   Enlarging        NaN                   Smooth
# 8120    Edible   Enlarging        NaN                   Smooth
# 8121    Edible   Enlarging        NaN                   Smooth
# 8122  Poisnous    Tapering        NaN                   Smooth
# 8123    Edible   Enlarging        NaN                   Smooth
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring
# 0                      Smooth                  White                  White
# 1                      Smooth                  White                  White
# 2                      Smooth                  White                  White
# 3                      Smooth                  White                  White
# 4                      Smooth                  White                  White
# ...                       ...                    ...                    ...
# 8119                   Smooth                 Orange                 Orange
# 8120                   Smooth                 Orange                 Orange
# 8121                   Smooth                 Orange                 Orange
# 8122                   Smooth                  White                  White
# 8123                   Smooth                 Orange                 Orange
#
# [8124 rows x 7 columns]

# %%
df[['class', 'veil-type', 'veil-color', 'ring-number','ring-type', 'spore-print-color', 'population', 'habitat']]
# 1, 4, 2, 4, 9, 6, 7
# Out:
#          class veil-type veil-color  ring-number   ring-type  \
# 0     Poisnous   Partial      White          1.0     Pendant
# 1       Edible   Partial      White          1.0     Pendant
# 2       Edible   Partial      White          1.0     Pendant
# 3     Poisnous   Partial      White          1.0     Pendant
# 4       Edible   Partial      White          1.0  Evanescent
# ...        ...       ...        ...          ...         ...
# 8119    Edible   Partial     Orange          1.0     Pendant
# 8120    Edible   Partial      Brown          1.0     Pendant
# 8121    Edible   Partial     Orange          1.0     Pendant
# 8122  Poisnous   Partial      White          1.0  Evanescent
# 8123    Edible   Partial     Orange          1.0     Pendant
#
#      spore-print-color population   habitat
# 0                Black  Scattered     Urban
# 1                Brown   Numerous   Grasses
# 2                Brown   Numerous  Meadowns
# 3                Black  Scattered     Urban
# 4                Brown   Abundant   Grasses
# ...                ...        ...       ...
# 8119              Buff  Clustered    Leaves
# 8120              Buff    Several    Leaves
# 8121              Buff  Clustered    Leaves
# 8122             White    Several    Leaves
# 8123            Orange  Clustered    Leaves
#
# [8124 rows x 8 columns]

# %%
df['habitat'].value_counts()
# Out:
# habitat
# Woods       3148
# Grasses     2148
# Paths       1144
# Leaves       832
# Urban        368
# Meadowns     292
# Waste        192
# Name: count, dtype: int64
